# %% [markdown]
# ![UPC-WS7A.png](attachment:UPC-WS7A.png)

# %% [markdown]
# ## NLP - Análisis de Sentimientos: Trump Banned from Twitter

# %% [markdown]
# ![trump_banned.jpg](attachment:trump_banned.jpg)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import networkx
from textblob import TextBlob

# %matplotlib inline

# %% [markdown]
# ### 1. Importación de datos (tweets)

# %%
data = pd.read_csv('data/tweets-trump-c.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7970 entries, 0 to 7969
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   text                7970 non-null   object
#  1   lang                7970 non-null   object
#  2   user-location       6516 non-null   object
#  3   place-country       7970 non-null   object
#  4   place-country_code  7970 non-null   object
#  5   user-screen_name    7970 non-null   object
#  6   Lat                 7970 non-null   float64
#  7   Lon                 7970 non-null   float64
#  8   lang_txt            7970 non-null   object
#  9   text_en             7970 non-null   object
#  10  text_cleaned        7923 non-null   object
# dtypes: float64(2), object(9)
# memory usage: 685.0+ KB

# %%
# Mantenemos en el df los tweets sin NA en la columna text_cleaned   
data = data[data['text_cleaned'].notna()]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7923 entries, 0 to 7969
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   text                7923 non-null   object
#  1   lang                7923 non-null   object
#  2   user-location       6486 non-null   object
#  3   place-country       7923 non-null   object
#  4   place-country_code  7923 non-null   object
#  5   user-screen_name    7923 non-null   object
#  6   Lat                 7923 non-null   float64
#  7   Lon                 7923 non-null   float64
#  8   lang_txt            7923 non-null   object
#  9   text_en             7923 non-null   object
#  10  text_cleaned        7923 non-null   object
# dtypes: float64(2), object(9)
# memory usage: 742.8+ KB

# %%
data.head()
# Out:
#                                                 text lang  \
# 0  Trump foi banido do Facebook!\nParabens Facebo...   pt
# 1  Coup attempt fallout: #trumpBanned #Trumpcenso...   en
# 2  #TrumpBanned \nTrump banido do Facebook indefi...   pt
# 3  Mark Zuckerberg bans @realDonaldTrump from Fac...   en
# 4  @Facebook doing the least.\nBanning Cheeto two...   en
#
#              user-location  place-country place-country_code user-screen_name  \
# 0                   Brasil         Brazil                 BR  psipauloalmeida
# 1               Queens, NY  United States                 US          BCNewsy
# 2                   Brasil         Brazil                 BR  psipauloalmeida
# 3           Palm Beach, FL  United States                 US        wpbf_todd
# 4  Eswatini, Azania, Terra      Swaziland                 SZ          thesuku
#
#          Lat        Lon    lang_txt  \
# 0 -19.918692 -43.959823  Portuguese
# 1  40.670880 -73.831187     English
# 2 -19.918692 -43.959823  Portuguese
# 3  26.533486 -80.112903     English
# 4 -26.517679  31.462823     English
#
#                                              text_en  \
# 0  Trump has been banned from Facebook!\nCongratu...
# 1  Coup attempt fallout: #trumpBanned #Trumpcenso...
# 2  # TrumpBanned\nTrump banned from Facebook inde...
# 3  Mark Zuckerberg bans @realDonaldTrump from Fac...
# 4  @Facebook doing the least.\nBanning Cheeto two...
#
#                                         text_cleaned
# 0  trump have be ban from facebookcongratulation ...
# 1  coup attempt fallout trumpbanne trumpcensore t...
# 2    trumpbannedtrump ban from facebook indefinitely
# 3  mark zuckerberg ban realdonaldtrump from faceb...
# 4  facebook do the leastbanne cheeto two week bef...

# %% [markdown]
# ### 2. Análisis de Sentimientos

# %% [markdown]
# Se puede utilizar textblob del paquete Python para calcular los valores de polaridad de los tweets individuales.
# * Empezamos creando objetos textblob, que asignan valores de polaridad a los tweets.
# * Luego se identifica el valor de polaridad utilizando el atributo .polarity del objeto texblob.

# %%
# definimos una funcion para analizar los sentimientos en cada texto del tweet
def analize_sentiment(tweet):
    '''
    Función de utilidad para clasificar la polaridad de un tweet
     usando textblob.
    '''
    analysis = TextBlob(tweet)
    if analysis.sentiment.polarity > 0:
        return 1
    elif analysis.sentiment.polarity == 0:
        return 0
    else:
        return -1

# %% [markdown]
# La forma en que funciona es que textblob ya proporciona un analizador entrenado (mucho más facil). **Textblob** puede trabajar con diferentes modelos de aprendizaje automático utilizados en el procesamiento del lenguaje natural. De todos modos, volviendo al código, solo agregaremos una columna adicional a nuestros datos. Esta columna contendrá el análisis de sentimiento y podemos trazar el dataframe para ver la actualización:

# %%
# Creamos una columna con el resultado del análisis:
data['SA'] = np.array([ analize_sentiment(tweet) for tweet in data['text_cleaned'] ])

data.head()
# Out:
#                                                 text lang  \
# 0  Trump foi banido do Facebook!\nParabens Facebo...   pt
# 1  Coup attempt fallout: #trumpBanned #Trumpcenso...   en
# 2  #TrumpBanned \nTrump banido do Facebook indefi...   pt
# 3  Mark Zuckerberg bans @realDonaldTrump from Fac...   en
# 4  @Facebook doing the least.\nBanning Cheeto two...   en
#
#              user-location  place-country place-country_code user-screen_name  \
# 0                   Brasil         Brazil                 BR  psipauloalmeida
# 1               Queens, NY  United States                 US          BCNewsy
# 2                   Brasil         Brazil                 BR  psipauloalmeida
# 3           Palm Beach, FL  United States                 US        wpbf_todd
# 4  Eswatini, Azania, Terra      Swaziland                 SZ          thesuku
#
#          Lat        Lon    lang_txt  \
# 0 -19.918692 -43.959823  Portuguese
# 1  40.670880 -73.831187     English
# 2 -19.918692 -43.959823  Portuguese
# 3  26.533486 -80.112903     English
# 4 -26.517679  31.462823     English
#
#                                              text_en  \
# 0  Trump has been banned from Facebook!\nCongratu...
# 1  Coup attempt fallout: #trumpBanned #Trumpcenso...
# 2  # TrumpBanned\nTrump banned from Facebook inde...
# 3  Mark Zuckerberg bans @realDonaldTrump from Fac...
# 4  @Facebook doing the least.\nBanning Cheeto two...
#
#                                         text_cleaned  SA
# 0  trump have be ban from facebookcongratulation ...   0
# 1  coup attempt fallout trumpbanne trumpcensore t...   0
# 2    trumpbannedtrump ban from facebook indefinitely   0
# 3  mark zuckerberg ban realdonaldtrump from faceb...   0
# 4  facebook do the leastbanne cheeto two week bef...   0

# %%
# Cree un df que contenga el valor de polaridad y el texto del tweet
sentiment_df = data[['text_cleaned', 'SA']]

sentiment_df.head(15)
# Out:
#                                          text_cleaned  SA
# 0   trump have be ban from facebookcongratulation ...   0
# 1   coup attempt fallout trumpbanne trumpcensore t...   0
# 2     trumpbannedtrump ban from facebook indefinitely   0
# 3   mark zuckerberg ban realdonaldtrump from faceb...   0
# 4   facebook do the leastbanne cheeto two week bef...   0
# 5   so donaldtrump have be ban from facebook indef...   1
# 6   tromb be a dictator under the skin this be bal...   0
# 7   twitter tonight be like when scream child fina...   0
# 8   base on trump time see over the past year a ho...  -1
# 9   ohhhhh spot on trumpisacompletefailure trumpbanne   0
# 10  twitter suspend the trump account and not a jo...   0
# 11  other than what be supremiosh let go to the re...  -1
# 12  i guess will have to say a lot more at the pre...   1
# 13  fyi twitter owe no one shit with regard to a p...   1
# 14                         trumpbanne thankyoutwitter   0

# %% [markdown]
# **Análisis de los resultados**

# %% [markdown]
# Para tener una forma sencilla de verificar los resultados, contaremos el número de tweets neutrales, positivos y negativos y extraeremos los porcentajes.

# %%
pos = len(sentiment_df[sentiment_df['SA'] > 0]. value_counts())
neu = len(sentiment_df[sentiment_df['SA'] == 0]. value_counts())
neg = len(sentiment_df[sentiment_df['SA'] < 0]. value_counts())
tot =  pos+neu+neg
#print (pos, neu, neg, pos+neu+neg)

# %% [markdown]
# Imprimimos los porcentajes:

# %%
# Visualizamos los %:

print("Porcentaje de tweets positivos : {}%".format(round(pos/tot*100,2)))
print("Porcentaje de tweets neutrales : {}%".format(round(neu/tot*100,2)))
print("Porcentaje de tweets negativos : {}%".format(round(neg/tot*100,2)))
# Out:
# Porcentaje de tweets positivos : 27.3%
# Porcentaje de tweets neutrales : 53.63%
# Porcentaje de tweets negativos : 19.07%

# %% [markdown]
# Estos valores de polaridad se pueden trazar en un histograma, lo que puede ayudar a resaltar el sentimiento general (es decir, más positividad o negatividad) hacia el sujeto.

# %%
fig, ax = plt.subplots(figsize=(8, 6))

# Plot histogram of the polarity values
sentiment_df.hist(bins=[-1, -0.75, -0.5, -0.25, 0.25, 0.5, 0.75, 1],
             ax=ax,
             color="purple")

plt.title("Sentimentos de Tweets sobre Trump Banned en Twitter")
plt.show()

# %% [markdown]
# ### 3. Nube de Palabras (WordCloud)

# %%
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
text = " ".join(tweet for tweet in sentiment_df['text_cleaned'])
print ("Existen {} palabras al combinar todos los tweets limpios.".format(len(text)))
# Out:
# Existen 594869 palabras al combinar todos los tweets limpios.

# %%
stopwords = set(STOPWORDS)
# Eliminaremos las palabras de coleccon 
stopwords.update(["trump", "trumpbanned", "wearetrump", "realdonaldtrump"])

# Generate a word cloud image
wordcloud = WordCloud(stopwords=stopwords, background_color="GhostWhite", width=800, height=800, margin=2,collocations=False,
                      font_step=2).generate(text)

# %%
plt.figure(figsize=(16,9), facecolor='k')
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.title("Wordcloud (Nube de Palabras) sobre Trump Banned en Twitter")
plt.show()

# %% [markdown]
# ### 4. Ubicación de los tweets en un mapa

# %%
import seaborn as sns
import matplotlib.pyplot as plt

import plotly.express as px
import plotly.io as pio

fig = px.scatter_geo(data, lat='Lat', lon='Lon', 
                     color='place-country', #size='New cases', size_max=20,
                     hover_name='user-screen_name', 
                     hover_data=[ 'text_cleaned',  'place-country',
                                 'user-location'], template='seaborn')

fig.update_layout(
    title_text = "Subconjunto de tweets con ubicación exacta",
    
    geo=dict(showframe=False, showcoastlines=False, 
             projection_type='equirectangular'),
    
    annotations = [dict(x=-0.04, y=0.95, xref='paper', yref='paper',
        text='Del total de tweets, solo el ~ 7% incluye ' \
                'la ubicación exacta. Esta proporción se mantiene siempre.', showarrow = False)]
)

fig.update_geos(resolution=110, showcountries=True, 
                lataxis_range=[-55, 90], lonaxis_range=[-180, 180])
fig.show()
# Out:
# <div>                            <div id="7f903647-93a1-406e-baa2-3d2b8729a187" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7f903647-93a1-406e-baa2-3d2b8729a187")) {                    Plotly.newPlot(                        "7f903647-93a1-406e-baa2-3d2b8729a187",                        [{"customdata":[["trump have be ban from facebookcongratulation on facebookcongratulation facebooktrumpbanne facebook ban","Brazil","Brasil"],["trumpbannedtrump ban from facebook indefinitely","Brazil","Brasil"],["trumpbanne","Brazil","Vitória, Brasil"],["here lie an expelabag or babaegg of trump drool so much die for the sack trumpbanne invasion capitolio","Brazil","RIO DE JANEIRO"],["i have more than follower and today only business be ugly folllow trumpbanned raulveiga bolsonarosp bolsonarosp communism","Brazil","ÜT: -15.81383,-47.813056"],["could take and put in a straitjacket trumpbanne","Brazil",null],["this be a real attack on freedom of expression and the international press be silent trumpbanne","Brazil","Macapá, Brasil"],["twitterbrasil twitter become a puppet of the pcc chinese communist party embaixadachina","Brazil","itaguaí,rj, brasil"],["carlosbolsonaro in case do not know social network be not state institution be private company and blo","Brazil","Brasil"],["trumpbanne wearmask","Brazil","Ceará, Brasil"],["great humanitarian achievement congratulation twittertrumpbanne","Brazil","Brasília"],["trumpbanne","Brazil","Cotia, Brasil"],["bolsominion be dumb enough to vote for an unclassifiable one like jairbolsonarobut i never imagine","Brazil","Tiros MG - Brasília DF"],["with social network be a ferocious beast fiercewithout walk around and even change voice trumpbanne","Brazil","Manaus"],["trumpbanne donaldtrump censurano","Brazil",null],["look at the type of people who follow trump imagine the type of people who follow bolsonarogenocida disgust revulsion the h","Brazil",null],["ah understand the dictatorial government fan big corporation trumpbanne","Brazil","Vitória, Brasil"],["exame lover the horned capitol invader will be ceo of loser donald trump private network bolsonar","Brazil","Sampa City - SP   Brazil"],["cheeto must be hope that pornhub do not cancel access to premium all have leave trump trumpbanne","Brazil","São Paulo, Brasil"],["generalflynnbanne trumpbanne","Brazil","Tracuateua, Brasil, #FlatEarth"],["if trump can no long use american social network can use tiktok just imagine the app from china use","Brazil","Rio de janeiro"],["trumpbanne be the most imbecile i do not know who still sympathize with a guy as ridiculous as","Brazil","Mcz Beach"],["grande dia trumpbannedtrumpinsurrectiontrumpimpeachment","Brazil","Vitória, Brasil"],["kamalaharris trumpbanne","Brazil","Duque de Caxias, Brasil"],["if in the example country of democracy united states manage to overthrow a clearly reelect politician imagine in","Brazil",null],["oantagonista marialcab wearetrump","Brazil",null],["wearetrump","Brazil",null],["estadao tucapinheirodf for the value wearetrump","Brazil",null],["wearetrump","Brazil",null],["marleneffl this way to the stalkwearetrump","Brazil",null],["wearetrump","Brazil",null],["social medium dictatorsthey will not shut up wearetrump","Brazil","Estados Unidos"],["yes wearetrump","Brazil",null],["wearetrump","Brazil","Brasília, Brasil"],["i only deliver the point if on the the democrat be swear in otherwise ill keep wait wearetrump","Brazil",null],["wearetrump","Brazil",null],["honori look at flag and i remain firm and strong support pr and the entire gov jb teamwearetrump","Brazil","Brasil"],["bonner be the big bastard there isglobolixojournal garbagebolsonarotemreasonwearetrump","Brazil","Brasil"],["josemedeirosmt do know what the medeiros problem iswe conservative play with ...
