# %% [markdown]
# ### Algoritmo Genético - Ejemplo #3

# %%
# Crear una cadena de destino, comenzando desde una cadena aleatoria usando algoritmo genético

# %%
import random

# %%
# Número de individuos en cada generación
POPULATION_SIZE = 100

# %%
#Genes válidos
GENES = '''abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOP
QRSTUVWXYZ 1234567890, .-;:_!"#%&/()=?@${[]}'''

# %%
# Cadena de destino que se generará
TARGET = "Pablito clavo un clavito"

# %%
class Individual(object):
    '''
    Clase que representa al individuo en la población
    '''
    def __init__(self, chromosome):
        self.chromosome = chromosome 
        self.fitness = self.cal_fitness()
  
    @classmethod
    def mutated_genes(self):
        '''
        crear genes aleatorios para la mutación
        '''
        global GENES
        gene = random.choice(GENES)
        return gene
  
    @classmethod
    def create_gnome(self):
        '''
        crear un cromosoma o cadena de genes
        '''
        global TARGET
        gnome_len = len(TARGET)
        return [self.mutated_genes() for _ in range(gnome_len)]
  
    def mate(self, par2):
        '''
        Realizar apareamiento y producir nueva descendencia
        '''
  
        # cromosoma para la descendencia
        child_chromosome = []
        for gp1, gp2 in zip(self.chromosome, par2.chromosome):    
  
            # probabilidad aleatoria
            prob = random.random()
  
            # si prob es menor que 0.45, insertar gen
            # del padre 1 
            if prob < 0.45:
                child_chromosome.append(gp1)
  
            # si prob esta entre 0.45 y 0.90, insertar gen
            # del padre 2
            elif prob < 0.90:
                child_chromosome.append(gp2)
  
            # de lo contrario, insertar un gen aleatorio (mutado),
            # para mantener la diversidad
            else:
                child_chromosome.append(self.mutated_genes())
  
        # crear un nuevo individuo (descendencia) usando
        # cromosoma generado para la descendencia
        return Individual(child_chromosome)
  
    def cal_fitness(self):
        '''
        Calcular la puntuación de aptitud, es el número de caracteres 
        en la cadena origen que difieren de la cadena de destino
        '''
        global TARGET
        fitness = 0
        for gs, gt in zip(self.chromosome, TARGET):
            if gs != gt: fitness+= 1
        return fitness

# %%
# Código principal
def main():
    global POPULATION_SIZE
  
    #la generación actual
    generation = 1
  
    found = False
    population = []
  
    # crear población inicial
    for _ in range(POPULATION_SIZE):
                gnome = Individual.create_gnome()
                population.append(Individual(gnome))
  
    while not found:
  
        # ordenar la población en orden creciente de puntuación de aptitud física
        population = sorted(population, key = lambda x:x.fitness)
  
        # si el individuo alcanza el puntaje de aptitud más bajo, es decir.
        # 0 entonces sabemos que hemos llegado al objetivo
        # y romper el bucle
        if population[0].fitness <= 0:
            found = True
            break
  
        # De lo contrario, se generan nuevos descendientes para la nueva generación
        new_generation = []
  
        # Realizar elitismo, lo que significa que el 10% de la población más apta
        # pasa a la siguiente generación
        s = int((10*POPULATION_SIZE)/100)
        new_generation.extend(population[:s])
  
        # Del 50% de la población más apta, los individuos
        # se aparearán para producir descendencia
        s = int((90*POPULATION_SIZE)/100)
        for _ in range(s):
            parent1 = random.choice(population[:50])
            parent2 = random.choice(population[:50])
            child = parent1.mate(parent2)
            new_generation.append(child)
  
        population = new_generation
  
        print("Generación: {}\tString: {}\tFitness: {}".\
              format(generation,
              "".join(population[0].chromosome),
              population[0].fitness))
  
        generation += 1
  
      
    print("Generación: {}\tString: {}\tFitness: {}".\
          format(generation,
          "".join(population[0].chromosome),
          population[0].fitness))

# %%
# Ejecutamos el codigo
main()
# Out:
# Generación: 1	String: 0Vn4;t=_c6VS[-uTJM1[twUU	Fitness: 21
# Generación: 2	String: 0Vn4;t=_c6VS[-uTJM1[twUU	Fitness: 21
# Generación: 3	String: ..-l(g=_c2:v[ju6T/0ct.}U	Fitness: 20
# Generación: 4	String: ..-l(g=_c2:v[ju6T/0ct.}U	Fitness: 20
# Generación: 5	String: PV!ti9#6;#AMXx.r &"avyy%	Fitness: 19
# Generación: 6	String: Po!liO#PTMAMIx.n &Gavyy%	Fitness: 17
# Generación: 7	String: Po!liO#PTMAMIx.n &Gavyy%	Fitness: 17
# Generación: 8	String: [Vfliu=kcM:vo4uT e_."iUF	Fitness: 16
# Generación: 9	String: [Vfliu=kcM:vo4uT e_."iUF	Fitness: 16
# Generación: 10	String: PVfliVmkcM:voOuY e#av7tF	Fitness: 13
# Generación: 11	String: PgblNto "MVsJ9un ul{v{tF	Fitness: 12
# Generación: 12	String: PgblNto "MVsJ9un ul{v{tF	Fitness: 12
# Generación: 13	String: PgblNto "MVsJ9un ul{v{tF	Fitness: 12
# Generación: 14	String: PVblNzB 8MPv 4un c1avitF	Fitness: 11
# Generación: 15	String: PVblNzB 8MPv 4un c1avitF	Fitness: 11
# Generación: 16	String: P0dlitG cM:vAxun cTavit7	Fitness: 9
# Generación: 17	String: P0dlitG cM:vAxun cTavit7	Fitness: 9
# Generación: 18	String: P0dlitG cM:vAxun cTavit7	Fitness: 9
# Generación: 19	String: P0dlitG cM:vAxun cTavit7	Fitness: 9
# Generación: 20	String: P0dlitG cM:vAxun cTavit7	Fitness: 9
# Generación: 21	String: P;dliuo c.vvo9un u"avito	Fitness: 8
# Generación: 22	String: P;dliuo c.vvo9un u"avito	Fitness: 8
# Generación: 23	String: P;dliuo c.vvo9un u"avito	Fitness: 8
# Generación: 24	String: P[blito cM:vohun c;avit]	Fitness: 6
# Generación: 25	String: P[blito cM:vohun c;avit]	Fitness: 6
# Generación: 26	String: P[blito cM:vohun c;avit]	Fitness: 6
# Generación: 27	String: PcZlito cM?vo un cSavito	Fitness: 5
# Generación: 28	String: PcZlito cM?vo un cSavito	Fitness: 5
# Generación: 29	String: PcZlito cM?vo un cSavito	Fitness: 5
# Generación: 30	String: PcZlito cM?vo un cSavito	Fitness: 5
# Generación: 31	String: PcZlito cM?vo un cSavito	Fitness: 5
# Generación: 32	String: PcZlito cM?vo un cSavito	Fitness: 5
# Generación: 33	String: PcZlito cM?vo un cSavito	Fitness: 5
# Generación: 34	String: P[blito c
# vvo un coavito	Fitness: 4
# Generación: 35	String: P[blito c
# vvo un coavito	Fitness: 4
# Generación: 36	String: P[blito c
# vvo un coavito	Fitness: 4
# Generación: 37	String: P[blito c
# vvo un coavito	Fitness: 4
# Generación: 38	String: P[blito c
# vvo un coavito	Fitness: 4
# Generación: 39	String: P[blito c
# vvo un coavito	Fitness: 4
# Generación: 40	String: P[blito c
# vvo un coavito	Fitness: 4
# Generación: 41	String: P[blito c
# vvo un coavito	Fitness: 4
# Generación: 42	String: P[blito c
# vvo un coavito	Fitness: 4
# Generación: 43	String: P[blito c
# vvo un coavito	Fitness: 4
# Generación: 44	String: Pablito c
# vvo un cvavito	Fitness: 3
# Generación: 45	String: Pablito c
# vvo un cvavito	Fitness: 3
# Generación: 46	String: Pablito c
# vvo un cvavito	Fitness: 3
# Generación: 47	String: Pablito c
# vvo un cvavito	Fitness: 3
# Generación: 48	String: Pablito c
# vvo un cvavito	Fitness: 3
# Generación: 49	String: Pablito c
# vvo un cvavito	Fitness: 3
# Generación: 50	String: Pablito c
# vvo un cvavito	Fitness: 3
# Generación: 51	String: Pablito c
# vvo un cvavito	Fitness: 3
# Generación: 52	String: Pablito c
# vvo un cvavito	Fitness: 3
# Generación: 53	String: Pablito c
# vvo un cvavito	Fitness: 3
# Generación: 54	String: Pablito c
# vvo un cvavito	Fitness: 3
# Generación: 55	String: Pablito c
# vvo un cvavito	Fitness: 3
# Generación: 56	String: Pablito c
# vvo un cvavito	Fitness: 3
# Generación: 57	String: Pablito c
# vvo un cvavito	Fitness: 3
# Generación: 58	String: Pablito c
# vvo un cvavito	Fitness: 3
# Generación: 59	String: Pablito c
# vvo un cvavito	Fitness: 3
# Generación: 60	String: Pablito c
# vvo un cvavito	Fitness: 3
# Generación: 61	String: Pablito c
#
# vo un clavito	Fitness: 2
# Generación: 62	String: Pablito c
#
# vo un clavito	Fitness: 2
# Generación: 63	String: Pablito c
#
# vo un clavito	Fitness: 2
# Generación: 64	String: Pablito c
#
# vo un clavito	Fitness: 2
# Generación: 65	String: Pablito c
#
# vo un clavito	Fitness: 2
# Generación: 66	String: Pablito c
#
# vo un clavito	Fitness: 2
# Generación: 67	String: Pablito c
#
# vo un clavito	Fitness: 2
# Generación: 68	String: Pablito c
#
# vo un clavito	Fitness: 2
# Generación: 69	String: Pablito c
#
# vo un clavito	Fitness: 2
# Generación: 70	String: Pablito cDavo un clavito	Fitness: 1
# Generación: 71	String: Pablito cDavo un clavito	Fitness: 1
# Generación: 72	String: Pablito cDavo un clavito	Fitness: 1
# Generación: 73	String: Pablito cDavo un clavito	Fitness: 1
# Generación: 74	String: Pablito cDavo un clavito	Fitness: 1
# Generación: 75	String: Pablito clavo un clavito	Fitness: 0
